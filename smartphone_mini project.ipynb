# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("smartphone_usage_365_days.csv")

# %%
# Task-1
print("----- HEAD -----")
print(df.head())

print("----- TAIL -----")
print(df.tail())

print("----- INFO -----")
print(df.info())

print("----- DESCRIBE -----")
print(df.describe())
